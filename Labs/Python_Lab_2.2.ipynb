# %% [markdown]
# # Python_Lab_2.2

# %% [markdown]
# ### Task 1
# 1. Write a program that prompts the user to enter two numbers and prints their division. Handle cases where the user enters non-numeric values or attempts to divide by zero using a try-except block.

# %%
def divide_numbers():
    try:
        # Prompt the user to enter two numbers
        num1 = float(input("Enter the first number: "))  # Convert input to float
        num2 = float(input("Enter the second number: "))  # Convert input to float

        # Perform the division
        result = num1 / num2
        print(f"The result of {num1} divided by {num2} is: {result}")

    except ValueError:
        # Handle non-numeric input
        print("Error: Please enter valid numeric values.")
    except ZeroDivisionError:
        # Handle division by zero
        print("Error: Division by zero is not allowed.")

# Call the function to execute the program
divide_numbers()

# %% [markdown]
# ### Task 2
# - Use "Random" library to do the following:
#     1. Create a list of random numbers using list comprehension.
#     2. Create a list of squares of the even numbers from random numbers using list comprehension.
#     3. Create a list of tuples (number, square) for random numbers using list comprehension.

# %%
import random
# Generate 10 random integers between 1 and 100
random_numbers = [random.randint(1, 100) for _ in range(10)]
print("Random Numbers:", random_numbers)

# 2. Create a list of squares of the even numbers from random numbers using list comprehension
squares_of_even = [num ** 2 for num in random_numbers if num % 2 == 0]
print("Squares of Even Numbers:", squares_of_even)

# 3. Create a list of tuples (number, sequence) for random numbers using list comprehension
number_tuples = [(num, index) for index, num in enumerate(random_numbers)]
print("List of Tuples (Number, Sequence):", number_tuples)
# Out:
# Random Numbers: [37, 46, 49, 90, 72, 85, 12, 37, 96, 30]
# Squares of Even Numbers: [2116, 8100, 5184, 144, 9216, 900]
# List of Tuples (Number, Sequence): [(37, 0), (46, 1), (49, 2), (90, 3), (72, 4), (85, 5), (12, 6), (37, 7), (96, 8), (30, 9)]

# %% [markdown]
# ### Task 3
# - Create a dictionary where the keys are numbers from 1 to 5 and the values are list of their squares and cubes.
#
#   - **hint**: use dictionary of list comprehension.
#
# - Create a dictionary from two lists (one with keys and one with values) using dictionary comprehension.

# %%
# 1. Create a dictionary where the keys are numbers from 1 to 5 
# and the values are lists of their squares and cubes using dictionary comprehension.
squares_and_cubes = {i: [i**2, i**3] for i in range(1, 6)}
print("Squares and Cubes Dictionary:", squares_and_cubes)

# 2. Create a dictionary from two lists using dictionary comprehension
keys = ['a', 'b', 'c']
values = [1, 2, 3]
combined_dict = {keys[i]: values[i] for i in range(len(keys))}
print("Combined Dictionary from Lists:", combined_dict)

# %% [markdown]
# ### Task 4
# - Given a dictionary where keys are student names and values are lists of their scores, write a function that updates the scores of students who have achieved a perfect score (100) by adding a bonus of 5 points to each score. Use dictionary comprehension to achieve this.
#
#     - Implement the function add_bonus_to_perfect_scores(student_scores) that adds a bonus of 5 points to each score of students who have achieved a perfect score (100).

# %%
def add_bonus_to_perfect_scores(student_scores):
    # Using dictionary comprehension to update the scores
    updated_scores = {
        name: [score + 5 if score == 100 else score for score in scores]
        for name, scores in student_scores.items()
    }
    return updated_scores

# Example usage
student_scores = {
    'Ahmad': [95, 100, 88],
    'Mohammed': [100, 70, 100],
    'Ali': [80, 90, 85],
    'Fahad': [100, 100, 100]
}

updated_scores = add_bonus_to_perfect_scores(student_scores)
print("Updated Student Scores:", updated_scores)
# Out:
# Updated Student Scores: {'Ahmad': [95, 105, 88], 'Mohammed': [105, 70, 105], 'Ali': [80, 90, 85], 'Fahad': [105, 105, 105]}
